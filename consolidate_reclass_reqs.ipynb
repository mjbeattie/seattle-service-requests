# %% [markdown]
# # consolidate_reclass_reqs
# ## June 2, 2024
# ### University of Oklahoma
# This script consolidates the reclassified service request data files into one csv for uploading to the PostgreSQL database.

# %%
import pandas as pd, os

path = 'C:\\Users\\mjbea\\OneDrive\\GitHub\\seattle-service-requests-data\\Reclassified Requests\\'

# Initialize an empty list of dataframes
dfs = []
for i in range(0,62):
    filename = path + 'reclassified_fifi_reqs_' + str(i) + '.csv'
    df = pd.read_csv(filename, index_col=None, encoding="utf-8", header=0)
    dfs.append(df)
    
# Concatenate all the dataframes into one
big_frame = pd.concat(dfs, ignore_index=True)

# %%
big_frame
# Out:
#         servreqid                                               text  \
# 0       190226346  Sign down on sidewalk. SE corner of 75th St NE...
# 1       190229680                          scl property closed sign
# 2       190230845  No parking signs on the northbound lane of Fai...
# 3       190233656                    Stop sign down after collision
# 4       190234544  The street sign showing directions to Magnuson...
# ...           ...                                                ...
# 305965  248373578  Trash can need emptied, since it's not in the ...
# 305966  248398823  Here are 5 examples of their locations on Pike...
# 305967  249727562                                             Litter
# 305968  249827058                              Graffiti on trashcan
# 305969  250194537  LOTs of garbage and litter, hazardous material...
#
#                                   origid                                id  \
# 0       SDOT-Sign and Signal Maintenance  SDOT-Sign and Signal Maintenance
# 1       SDOT-Sign and Signal Maintenance  SDOT-Sign and Signal Maintenance
# 2       SDOT-Sign and Signal Maintenance  SDOT-Sign and Signal Maintenance
# 3       SDOT-Sign and Signal Maintenance  SDOT-Sign and Signal Maintenance
# 4       SDOT-Sign and Signal Maintenance  SDOT-Sign and Signal Maintenance
# ...                                  ...                               ...
# 305965            SPU-Public Litter Cans            SPU-Public Litter Cans
# 305966            SPU-Public Litter Cans            SPU-Public Litter Cans
# 305967            SPU-Public Litter Cans            SPU-Public Litter Cans
# 305968            SPU-Public Litter Cans            SPU-Public Litter Cans
# 305969            SPU-Public Litter Cans            SPU-Public Litter Cans
#
#         label  newlabel                             newid
# 0           7         7  SDOT-Sign and Signal Maintenance
# 1           7         0               CSB-General Inquiry
# 2           7         7  SDOT-Sign and Signal Maintenance
# 3           7         7  SDOT-Sign and Signal Maintenance
# 4           7         7  SDOT-Sign and Signal Maintenance
# ...       ...       ...                               ...
# 305965     15        14        SPU-Illegal Dumping Report
# 305966     15         9       SEA-Unauthorized Encampment
# 305967     15        14        SPU-Illegal Dumping Report
# 305968     15        13               SPU-Graffiti Report
# 305969     15        14        SPU-Illegal Dumping Report
#
# [305970 rows x 7 columns]

# %%
# Save the dataframe to a new csv
outfilename = path + 'all_reclass_fifi_reqs.csv'
big_frame.to_csv(outfilename, sep="|", index=False, encoding="utf-8")

# %%
little_frame = big_frame[0:10]
little_frame
outfilename2 = path + 'small_reclass_fifi_reqs.csv'
big_frame.to_csv(outfilename2, sep="|", index=False, encoding="utf-8")
